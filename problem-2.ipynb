# %%
import json
import csv
from os.path import exists

#Reading JSON file data
def read_apod_data(filename="apod_data.json"):
    try:
        # Open the JSON file and load its content
        with open(filename, "r") as f:
            data = json.load(f)  # Correct usage of json.load
            return data  # Return the loaded data

    except FileNotFoundError:
        print(f"The file {filename} was not found.")
    except PermissionError:
        print(f"Permission denied when accessing {filename}.")
    except json.JSONDecodeError:
        print(f"Error decoding JSON data in {filename}.")
    except Exception as e:
        print(f"An error occurred: {e}")

data = read_apod_data()

if data:
    for entry in data:
        print(f'Date for "{entry["title"]}": {entry["date"]}')
# Out:
# Date for "NGC 1232: A Grand Design Spiral Galaxy": 2024-01-01
# Date for "Rocket Transits Rippling Moon": 2024-01-02
# Date for "A SAR Arc from New Zealand": 2024-01-03
# Date for "Zeta Oph: Runaway Star": 2024-01-04
# Date for "Trapezium: At the Heart of Orion": 2024-01-05
# Date for "The Snows of Churyumov-Gerasimenko": 2024-01-06
# Date for "The Cat's Eye Nebula in Optical and X-ray": 2024-01-07
# Date for "The Phases of Venus": 2024-01-08
# Date for "Thor's Helmet": 2024-01-09
# Date for "The Light, the Dark, and the Dusty": 2024-01-10
# Date for "Quadrantids of the North": 2024-01-11
# Date for "Good Morning Moon": 2024-01-12
# Date for "Circling the Sun": 2024-01-13
# Date for "Dragon Aurora over Iceland": 2024-01-14
# Date for "Star Cluster IC 348 from Webb": 2024-01-15
# Date for "The Orion You Can Almost See": 2024-01-16
# Date for "America and the Sea of Serenity": 2024-01-17
# Date for "Northern Lights from the Stratosphere": 2024-01-18
# Date for "Jupiter over 2 Hours and 30 Minutes": 2024-01-19
# Date for "Falcon Heavy Boostback Burn": 2024-01-20
# Date for "The Upper Michigan Blizzard of 1938": 2024-01-21
# Date for "Shadows of Mountain and Moon": 2024-01-22
# Date for "Deep Nebulas: From Seagull to California": 2024-01-23
# Date for "Earth and Moon from Beyond": 2024-01-24
# Date for "Jyväskylä in the Sky": 2024-01-25
# Date for "Epsilon Tauri: Star with Planet": 2024-01-26
# Date for "Full Observatory Moon": 2024-01-27
# Date for "Pluto in True Color": 2024-01-28
# Date for "The Pleiades: Seven Dusty Sisters": 2024-01-29
# Date for "SLIM Lands on the Moon": 2024-01-30
# Date for "Camera Orion Rising": 2024-01-31
# Date for "NGC 1365: Majestic Island Universe": 2024-02-01
# Date for "NGC 1893 and the Tadpoles of IC 410": 2024-02-02
# Date for "Apollo 14: A View from Antares": 2024-02-03
# Date for "The Cone Nebula from Hubble": 2024-02-04
# Date for "In the Core of the Carina Nebula": 2024-02-05
# Date for "NGC 1566: A Spiral Galaxy from Webb and Hubble": 2024-02-06
# Date for "The Heart Shaped Antennae Galaxies": 2024-02-07
# Date for "Globular Star Cluster 47 Tuc": 2024-02-08
# Date for "When Roses Aren't Red": 2024-02-09
# Date for "The Shadow of Ingenuity's Damaged Rotor Blade": 2024-02-10
# Date for "Rocket Plume Shadow Points to the Moon": 2024-02-11
# Date for "HFG1 & Abell 6: Planetary Nebulae": 2024-02-12
# Date for "A January Wolf Moon": 2024-02-13
# Date for "Rosette Deep Field": 2024-02-14
# Date for "NGC 253: Dusty Island Universe": 2024-02-15
# Date for "Structure in the Tail of Comet 12P/Pons-Brooks": 2024-02-16
# Date for "Meteor over the Bay of Naples": 2024-02-17
# Date for "Hoag's Object: A Nearly Perfect Ring Galaxy": 2024-02-18
# Date for "Looking Sideways from the Parker Solar Probe": 2024-02-19
# Date for "AM1054: Stars Form as Galaxies Collide": 2024-02-20
# Date for "Seagull Nebula over Pinnacles' Peak": 2024-02-21
# Date for "A View Toward M106": 2024-02-22
# Date for "The Pencil Nebula Supernova Shock Wave": 2024-02-23
# Date for "Odysseus to the Moon": 2024-02-24
# Date for "A Phoenix Aurora over Iceland": 2024-02-25
# Date for "Martian Moon Eclipses Martian Moon": 2024-02-26
# Date for "Supernova Remnant Simeis 147": 2024-02-27
# Date for "Shades of Night": 2024-02-28
# Date for "Julius Caesar and Leap Days": 2024-02-29
# Date for "Odysseus and The Dish": 2024-03-01
# Date for "Odysseus on the Moon": 2024-03-02
# Date for "A Total Solar Eclipse Close-Up in Real Time": 2024-03-03
# Date for "Light Pillars Over Inner Mongolia": 2024-03-04
# Date for "NGC 2170: Angel Nebula Abstract Art": 2024-03-05
# Date for "M102: Edge-on Disk Galaxy": 2024-03-06
# Date for "The Crew-8 Nebula": 2024-03-07
# Date for "The Tarantula Zone": 2024-03-08
# Date for "Comet Pons-Brooks in Northern Spring": 2024-03-09
# Date for "A Total Eclipse at the End of the World": 2024-03-10
# Date for "A Full Plankton Moon": 2024-03-11
# Date for "A Galaxy-Shaped Rocket Exhaust Spiral": 2024-03-12
# Date for "The Seagull Nebula": 2024-03-13
# Date for "Moon Pi and Mountain Shadow": 2024-03-14
# Date for "Portrait of NGC 1055": 2024-03-15
# Date for "ELT and the Milky Way": 2024-03-16
# Date for "NGC 7714: Starburst after Galaxy Collision": 2024-03-17
# Date for "Comet Pons-Brooks' Swirling Coma": 2024-03-18
# Date for "A Picturesque Equinox Sunset": 2024-03-19
# Date for "The Eyes in Markarian's Galaxy Chain": 2024-03-20
# Date for "The Leo Trio": 2024-03-21
# Date for "Phobos: Moon over Mars": 2024-03-22
# Date for "Ares 3 Landing Site: The Martian Revisited": 2024-03-23
# Date for "Looking Back at an Eclipsed Earth": 2024-03-24
# Date for "Sonified: The Jellyfish Nebula Supernova Remnant": 2024-03-25
# Date for "Comet Pons-Brooks' Ion Tail": 2024-03-26
# Date for "The Coma Cluster of Galaxies": 2024-03-27
# Date for "Millions of Stars in Omega Centauri": 2024-03-28
# Date for "Galileo's Europa": 2024-03-29
# Date for "Medieval Astronomy from Melk Abbey": 2024-03-30
# Date for "Total Solar Eclipse Below the Bottom of the World": 2024-03-31
# Date for "Swirling Magnetic Field around Our Galaxy's Central Black Hole": 2024-04-01
# Date for "Detailed View of a Solar Eclipse Corona": 2024-04-02
# Date for "Unusual Nebula Pa 30": 2024-04-03
# Date for "Comet Pons-Brooks at Night": 2024-04-04
# Date for "The Solar Corona Unwrapped": 2024-04-05
# Date for "Unwinding M51": 2024-04-06
# Date for "A Total Solar Eclipse over Wyoming": 2024-04-07
# Date for "The Changing Ion Tail of Comet Pons-Brooks": 2024-04-08
# Date for "Moon's Shadow over Lake Magog": 2024-04-09
# Date for "Planets Around a Total Eclipse": 2024-04-10
# Date for "Eclipse in Seven": 2024-04-11
# Date for "Total Totality": 2024-04-12
# Date for "Palm Tree Partial Eclipse": 2024-04-13
# Date for "How a Total Solar Eclipse Ended": 2024-04-14
# Date for "The Cigar Galaxy from Hubble and Webb": 2024-04-15
# Date for "Filaments of the Vela Supernova Remnant": 2024-04-16
# Date for "Total Eclipse and Comets": 2024-04-17
# Date for "Facing NGC 1232": 2024-04-18
# Date for "The Great Carina Nebula": 2024-04-19
# Date for "Diamonds in the Sky": 2024-04-20
# Date for "Perijove 16: Passing Jupiter": 2024-04-21
# Date for "Moon and Smoke Rings from Mt. Etna": 2024-04-22
# Date for "Contrail Shadow X": 2024-04-23
# Date for "Dragon's Egg Bipolar Emission Nebula": 2024-04-24
# Date for "NGC 604: Giant Stellar Nursery": 2024-04-25
# Date for "Regulus and the Dwarf Galaxy": 2024-04-26
# Date for "All Sky Moon Shadow": 2024-04-27
# Date for "Rings Around the Ring Nebula": 2024-04-28
# Date for "Comet, Planet, Moon": 2024-04-29
# Date for "GK Per: Nova and Planetary Nebula": 2024-04-30
# Date for "IC 1795: The Fishhead Nebula": 2024-05-01
# Date for "M100: A Grand Design Spiral Galaxy": 2024-05-02
# Date for "Temperatures on Exoplanet WASP-43b": 2024-05-03
# Date for "3 ATs": 2024-05-04
# Date for "A Black Hole Disrupts a Passing Star": 2024-05-05
# Date for "A Total Solar Eclipse from Sliver to Ring": 2024-05-06
# Date for "Black Hole Accreting with Jet": 2024-05-07
# Date for "Visualization: A Black Hole Accretion Disk": 2024-05-08
# Date for "The Galaxy, the Jet, and a Famous Black Hole": 2024-05-09
# Date for "Simulation: Two Black Holes Merge": 2024-05-10
# Date for "AR 3664: Giant Sunspot Group": 2024-05-11
# Date for "Red Aurora over Poland": 2024-05-12
# Date for "AR 3664 on a Setting Sun": 2024-05-13
# Date for "The 37 Cluster": 2024-05-14
# Date for "AR 3664 at the Sun's Edge": 2024-05-15
# Date for "Aurora Georgia": 2024-05-16
# Date for "Aurora Banks Peninsula": 2024-05-17
# Date for "North Celestial Aurora": 2024-05-18
# Date for "Jupiter Diving": 2024-05-19
# Date for "Aurora Dome Sky": 2024-05-20
# Date for "CG4: The Globule and the Galaxy": 2024-05-21
# Date for "Green Aurora over Sweden": 2024-05-22
# Date for "Unraveling NGC 3169": 2024-05-23
# Date for "M78 from the Euclid Space Telescope": 2024-05-24
# Date for "Manicouagan Impact Crater from Space": 2024-05-25
# Date for "A Solar Filament Erupts": 2024-05-26
# Date for "Chamaeleon I Molecular Cloud": 2024-05-27
# Date for "Solar X Flare as Famous Active Region Returns": 2024-05-28
# Date for "Stairway to the Milky Way": 2024-05-29
# Date for "A Lunar Corona over Paris": 2024-05-30
# Date for "The Nebulous Realm of WR 134": 2024-05-31
# Date for "Stereo Helene": 2024-06-01
# Date for "Rotating Moon from LRO": 2024-06-02
# Date for "NGC 2403 in Camelopardalis": 2024-06-03
# Date for "Comet Pons-Brooks Develops Opposing Tails": 2024-06-04
# Date for "Shadow of a Martian Robot": 2024-06-05
# Date for "NGC 4565: Galaxy on Edge": 2024-06-06
# Date for "SH2-308: The Dolphin Head Nebula": 2024-06-07
# Date for "Pandora's Cluster of Galaxies": 2024-06-08
# Date for "How to Identify that Light in the Sky": 2024-06-09
# Date for "Sh2-132: The Lion Nebula": 2024-06-10
# Date for "Colorful Stars and Clouds near Rho Ophiuchi": 2024-06-11
# Date for "Aurora over Karkonosze Mountains": 2024-06-12
# Date for "Messier 66 Close Up": 2024-06-13
# Date for "RCW 85": 2024-06-14
# Date for "Prominences and Filaments on the Active Sun": 2024-06-15
# Date for "Animation: Black Hole Destroys Star": 2024-06-16
# Date for "Ou4: The Giant Squid Nebula": 2024-06-17
# Date for "Gigantic Jets over Himalayan Mountains": 2024-06-18
# Date for "NGC 6188: Dragons of Ara": 2024-06-19
# Date for "Sandy and the Moon Halo": 2024-06-20
# Date for "Hubble's NGC 1546": 2024-06-21
# Date for "Lynds Dark Nebula 1251": 2024-06-22
# Date for "The Colors of Saturn from Cassini": 2024-06-23
# Date for "JADES-GS-z14-0: A New Farthest Object": 2024-06-24
# Date for "The Dark Doodad Nebula": 2024-06-25
# Date for "Timelapse: Aurora, SAR, and the Milky Way": 2024-06-26
# Date for "Protostellar Outflows in Serpens": 2024-06-27
# Date for "Comet 13P/Olbers": 2024-06-28
# Date for "A Solstice Moon": 2024-06-29
# Date for "Earthrise: A Video Reconstruction": 2024-06-30
# Date for "Time Spiral": 2024-07-01
# Date for "NGC 602: Oyster Star Cluster": 2024-07-02
# Date for "M83: Star Streams and a Thousand Rubies": 2024-07-03
# Date for "A Beautiful Trifid": 2024-07-04
# Date for "Mount Etna Milky Way": 2024-07-05
# Date for "NGC 7789: Caroline's Rose": 2024-07-06
# Date for "Iridescent Clouds over Sweden": 2024-07-07
# Date for "Exoplanet Zoo: Other Stars": 2024-07-08
# Date for "Noctilucent Clouds over Florida": 2024-07-09
# Date for "A Sagittarius Triplet": 2024-07-10
# Date for "Globular Cluster Omega Centauri": 2024-07-11
# Date for "Jones-Emberson 1": 2024-07-12
# Date for "Solar System Family Portrait": 2024-07-13
# Date for "Meteor Misses Galaxy": 2024-07-14
# Date for "The Tadpole Galaxy from Hubble": 2024-07-15
# Date for "Cometary Globules": 2024-07-16
# Date for "Villarrica Volcano Against the Sky": 2024-07-17
# Date for "Messier 24: Sagittarius Star Cloud": 2024-07-18
# Date for "Anticrepuscular Rays at the Planet Festival": 2024-07-19
# Date for "Apollo 11 Landing Panorama": 2024-07-20
# Date for "King of Wings Hoodoo under the Milky Way": 2024-07-21
# Date for "Chamaeleon Dark Nebulas": 2024-07-22
# Date for "The Crab Nebula from Visible to X-Ray": 2024-07-23
# Date for "Exaggerated Moon": 2024-07-24
# Date for "NGC 7023: The Iris Nebula": 2024-07-25
# Date for "Facing NGC 6946": 2024-07-26
# Date for "Saturn at the Moon's Edge": 2024-07-27
# Date for "Sun Dance": 2024-07-28
# Date for "Milky Way over Uluru": 2024-07-29
# Date for "Arp 142: Interacting Galaxies from Webb": 2024-07-30
# Date for "Leopard Spots on Martian Rocks": 2024-07-31
# Date for "Comet Olbers over Kunetice Castle": 2024-08-01
# Date for "Mars Passing By": 2024-08-02
# Date for "Glory and Fog Bow": 2024-08-03
# Date for "Gaia: Here Comes the Sun": 2024-08-04
# Date for "Milky Way Over Tunisia": 2024-08-05
# Date for "Storm Cloud Over Texas": 2024-08-06
# Date for "Milky Way Behind Three Merlons": 2024-08-07
# Date for "Periodic Comet Swift-Tuttle": 2024-08-08
# Date for "A Perseid Below": 2024-08-09
# Date for "The Light, Dark, and Dusty Trifid": 2024-08-10
# Date for "Animation: Perseid Meteor Shower": 2024-08-11
# Date for "Perseid Meteors over Stonehenge": 2024-08-12
# Date for "Giant Jet from the International Space Station": 2024-08-13
# Date for "Meteors and Aurora over Germany": 2024-08-14
# Date for "Late Night Vallentuna": 2024-08-15
# Date for "Meteor Borealis": 2024-08-16
# Date for "Sky Full of Arcs": 2024-08-17
# Date for "A Solar Prominence Eruption from SDO": 2024-08-18
# Date for "IC 5146: The Cocoon Nebula": 2024-08-19
# Date for "Supermoon Beyond the Temple of Poseidon": 2024-08-20
# Date for "Fermi's 12-year All-Sky Gamma-ray Map": 2024-08-21
# Date for "The Dark Tower in Scorpius": 2024-08-22
# Date for "Supernova Remnant CTA 1": 2024-08-23
# Date for "South Pacific Shadowset": 2024-08-24
# Date for "Fresh Tiger Stripes on Saturn's Enceladus": 2024-08-25
# Date for "Perseid Meteors Over Inner Mongolia": 2024-08-26
# Date for "Moon Eclipses Saturn": 2024-08-27
# Date for "Tulip Nebula and Black Hole Cygnus X-1": 2024-08-28
# Date for "Star Factory Messier 17": 2024-08-29
# Date for "Southern Moonscape": 2024-08-30
# Date for "IFN and the NGC 7771 Group": 2024-08-31
# Date for "The Moon Dressed Like Saturn": 2024-09-01
# Date for "A Triangular Prominence Hovers Over the Sun": 2024-09-02
# Date for "Quarter Moon and Sister Stars": 2024-09-03
# Date for "NGC 6995: The Bat Nebula": 2024-09-04
# Date for "NGC 247 and Friends": 2024-09-05
# Date for "Ringed Ice Giant Neptune": 2024-09-06
# Date for "Small Moon Deimos": 2024-09-07
# Date for "M31: The Andromeda Galaxy": 2024-09-08
# Date for "Mars: Moon, Craters, and Volcanos": 2024-09-09
# Date for "Horsehead and Orion Nebulas": 2024-09-10
# Date for "A Night Sky over the Tatra Mountains": 2024-09-11
# Date for "Young Star Cluster NGC 1333": 2024-09-12
# Date for "Aurora Australis and the International Space Station": 2024-09-13
# Date for "The Moona Lisa": 2024-09-14
# Date for "Find the Man in the Moon": 2024-09-15
# Date for "Mercury's Vivaldi Crater from BepiColombo": 2024-09-16
# Date for "Melotte 15 in the Heart Nebula": 2024-09-17
# Date for "The Mermaid Nebula Supernova Remnant": 2024-09-18
# Date for "The Dark Seahorse of Cepheus": 2024-09-19
# Date for "A Hazy Harvest Moon": 2024-09-20
# Date for "Sunrise Shadows in the Sky": 2024-09-21
# Date for "Chicagohenge: Equinox in an Aligned City": 2024-09-22
# Date for "Comet Tsuchinshan-ATLAS Approaches": 2024-09-23
# Date for "NGC 6727: The Rampaging Baboon Nebula": 2024-09-24
# Date for "Comet A3 Through an Australian Sunrise": 2024-09-25
# Date for "The Great Globular Cluster in Hercules": 2024-09-26
# Date for "Stellar Streams in the Local Universe": 2024-09-27
# Date for "Rocket Eclipse at Sunset": 2024-09-28
# Date for "Seven Dusty Sisters": 2024-09-29
# Date for "Comet Tsuchinshan-ATLAS over Mexico": 2024-09-30
# Date for "Porphyrion: The Longest Known Black Hole Jets": 2024-10-01
# Date for "The Large Magellanic Cloud Galaxy": 2024-10-02
# Date for "Eclipse at Sunrise": 2024-10-03
# Date for "Comet at Moonrise": 2024-10-04
# Date for "M27: Not a Comet": 2024-10-05
# Date for "The Magnificent Tail of Comet McNaught": 2024-10-06
# Date for "The Long Tails Comet Tsuchinshan-ATLAS": 2024-10-07
# Date for "Annular Eclipse over Patagonia": 2024-10-08
# Date for "M106: A Spiral Galaxy with a Strange Center": 2024-10-09
# Date for "Five Bright Comets from SOHO": 2024-10-10
# Date for "Ring of Fire over Easter Island": 2024-10-11
# Date for "Northern Lights, West Virginia": 2024-10-12
# Date for "Aurora Timelapse Over Italian Alps": 2024-10-13
# Date for "Comet Tsuchinshan-ATLAS Over the Lincoln Memorial": 2024-10-14
# Date for "Animation: Comet Tsuchinshan-ATLAS Tails Prediction": 2024-10-15
# Date for "Colorful Aurora over New Zealand": 2024-10-16
# Date for "The Clipper and the Comet": 2024-10-17
# Date for "Most of Comet Tsuchinshan-ATLAS": 2024-10-18
# Date for "Comet Tsuchinshan-ATLAS Flys Away": 2024-10-19
# Date for "Dark Matter in a Simulated Universe": 2024-10-20
# Date for "Comet Tsuchinshan-ATLAS over California": 2024-10-21
# Date for "M16: Pillars of Star Creation": 2024-10-22
# Date for "Caught": 2024-10-23
# Date for "NGC 7293: The Helix Nebula": 2024-10-24
# Date for "Globular Star Cluster NGC 6752": 2024-10-25
# Date for "Phantoms in Cassiopeia": 2024-10-26
# Date for "LDN 43: The Cosmic Bat Nebula": 2024-10-27
# Date for "STEVE: A Glowing River over France": 2024-10-28
# Date for "NGC 602: Stars Versus Pillars from Webb": 2024-10-29
# Date for "NGC 7635: The Bubble Nebula": 2024-10-30
# Date for "Rigel and the Witch Head Nebula": 2024-10-31
# Date for "Spiral Galaxy NGC 6744": 2024-11-01
# Date for "Saturn at Night": 2024-11-02
# Date for "Jupiter Abyss": 2024-11-03
# Date for "M42: The Great Nebula in Orion": 2024-11-04
# Date for "Milky Way over Easter Island": 2024-11-05
# Date for "Comet Tsuchinshan-Atlas over the Dolomites": 2024-11-06
# Date for "Shell Galaxies in Pisces": 2024-11-07
# Date for "Helping Hand in Cassiopeia": 2024-11-08
# Date for "Neptune at Night": 2024-11-09
# Date for "Valles Marineris: The Grand Canyon of Mars": 2024-11-10
# Date for "The Unusual Tails of Comet Tsuchinshan-Atlas": 2024-11-11
# Date for "NGC 6888: The Crescent Nebula": 2024-11-12
# Date for "Barred Spiral Galaxy NGC 1365 from Webb": 2024-11-13
# Date for "IC 348 and Barnard 3": 2024-11-14
# Date for "Apollo 12 and Surveyor 3": 2024-11-15
# Date for "Pluto at Night": 2024-11-16
# Date for "LDN 1471: A Windblown Star Cavity": 2024-11-17
# Date for "Stars and Dust in the Pacman Nebula": 2024-11-18
# Date for "Undulatus Clouds over Las Campanas Observatory": 2024-11-19
# Date for "Earthset from Orion": 2024-11-20
# Date for "The Elephant's Trunk in Cepheus": 2024-11-21
# Date for "The Medusa Nebula": 2024-11-22
# Date for "Interplanetary Earth": 2024-11-23
# Date for "Journey to the Center of the Galaxy": 2024-11-24
# Date for "The Horsehead Nebula": 2024-11-25
# Date for "The Sombrero Galaxy from Webb and Hubble": 2024-11-26
# Date for "The Meteor and the Comet": 2024-11-27
# Date for "NGC 206 and the Star Clouds of Andromeda": 2024-11-28
# Date for "Messier 4": 2024-11-29
# Date for "Winter and Summer on a Little Planet": 2024-11-30
# Date for "Cosmic Latte: The Average Color of the Universe": 2024-12-01
# Date for "NGC 300: A Galaxy of Stars": 2024-12-02
# Date for "Ice Clouds over a Red Planet": 2024-12-03
# Date for "Driveway Analemma": 2024-12-04
# Date for "Stereo Jupiter near Opposition": 2024-12-05
# Date for "Xuyi Station and the Fireball": 2024-12-06
# Date for "Rocket Engine Fireplace": 2024-12-07

# %%
def analyze_apod_media(filename="apod_data.json"):
    try:
        # Read the APOD data from the file
        data = read_apod_data()
        
        if not data:  # If data is empty, return early
            return
        
        total_images = 0
        total_videos = 0
        detailed_explanation = ""
        detailed_date = ""
        
        for entry in data:
            # Count media types
            if entry["media_type"] == "image":
                total_images += 1
            elif entry["media_type"] == "video":
                total_videos += 1
                
            # Find the date with the detailed explanation
            if len(entry["explanation"]) > len(detailed_explanation):
                detailed_explanation = entry["explanation"]
                detailed_date = entry["date"]
        
        print(f"Total Images: {total_images}")
        print(f"Total Videos: {total_videos}")
        print(f"Longest Explanation on {detailed_date}: {detailed_explanation}")
        
    except Exception as e:
        print(f"Error in analyzing data: {e}")
        
analyze_apod_media()
# Out:
# Total Images: 314
# Total Videos: 27
# Longest Explanation on 2024-07-15: Why does this galaxy have such a long tail?  In this stunning vista, based on image data from the Hubble Legacy Archive, distant galaxies form a dramatic backdrop for disrupted spiral galaxy Arp 188, the Tadpole Galaxy. The cosmic tadpole is a mere 420 million light-years distant toward the northern constellation of the Dragon (Draco). Its eye-catching tail is about 280 thousand light-years long and features massive, bright blue star clusters. One story goes that a more compact intruder galaxy crossed in front of Arp 188 - from right to left in this view - and was slung around behind the Tadpole by their gravitational attraction. During the close encounter, tidal forces drew out the spiral galaxy's stars, gas, and dust forming the spectacular tail. The intruder galaxy itself, estimated to lie about 300 thousand light-years behind the Tadpole, can be seen through foreground spiral arms at the upper right. Following its terrestrial namesake, the Tadpole Galaxy will likely lose its tail as it grows older, the tail's star clusters forming smaller satellites of the large spiral galaxy.   APOD in world languages: Arabic (IG), Bulgarian, Catalan, Chinese (Beijing), Chinese (Taiwan), Czech, Dutch, Farsi, French, German, Hebrew, Japanese, Portuguese, Russian, Serbian, Slovenian,  Spanish, Taiwanese, Turkish, and  Ukrainian

# %%
#Function for converting json file into csv format
def json_to_csv(json_filename="apod_data.json", csv_filename="apod_summary.csv"):
    # Read the JSON data
    with open(json_filename, "r") as f:
        data = json.load(f)

    # Extract the necessary fields (date, title, media_type, url)
    proc = [[entry["date"], entry["title"], entry["media_type"], entry["url"]] for entry in data]

    # Check if CSV file exists; if not, write the header
    if not exists(csv_filename):
        proc.insert(0, ["date", "title", "media_type", "url"])

    # Write the data to the CSV file
    with open(csv_filename, "a", newline="") as f:
        writer = csv.writer(f)
        writer.writerows(proc)

# Example usage
json_to_csv("apod_data.json", "apod_summary.csv")
